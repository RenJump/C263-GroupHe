# %%
import numpy as np
import pandas as pd

# %%
feature_ids = ['slot_id_target_enc',
'user_id_task_id_nunique_target_enc',
'user_id_task_id_nunique',
'user_id_adv_id_nunique',
'user_id_adv_id_nunique_target_enc',
'user_id_count',
'slot_id_count',
'user_id_adv_prim_id_nunique',
'adv_id_target_enc',
'user_id_slot_id_nunique_target_enc',
'app_second_class_target_enc',
'task_id_target_enc',
'user_id_count_target_enc',
'user_id_target_enc',
'user_id_adv_prim_id_nunique_target_enc',
'emui_dev_count',
'age_adv_prim_id_nunique_target_enc',
'u_feedLifeCycle',
'adv_prim_id_target_enc',
'age_task_id_nunique_target_enc',
'app_second_class_count',]

# 打印列表
print(feature_ids)
# Out:
# ['slot_id_target_enc', 'user_id_task_id_nunique_target_enc', 'user_id_task_id_nunique', 'user_id_adv_id_nunique', 'user_id_adv_id_nunique_target_enc', 'user_id_count', 'slot_id_count', 'user_id_adv_prim_id_nunique', 'adv_id_target_enc', 'user_id_slot_id_nunique_target_enc', 'app_second_class_target_enc', 'task_id_target_enc', 'user_id_count_target_enc', 'user_id_target_enc', 'user_id_adv_prim_id_nunique_target_enc', 'emui_dev_count', 'age_adv_prim_id_nunique_target_enc', 'u_feedLifeCycle', 'adv_prim_id_target_enc', 'age_task_id_nunique_target_enc', 'app_second_class_count']

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import jensenshannon
from scipy.stats import wasserstein_distance
from tqdm import tqdm

raw_path = r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\real.csv'
data_path =     [
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv']
def normalize_array(x):
    for col_id in range(x.shape[1]):
        x[:, col_id] = (x[:, col_id] - np.mean(x[:, col_id])) / np.std(x[:, col_id])

for task in data_path:
    print('-----------------------')
    print(task)
    original = pd.read_csv(task)
    original = original[feature_ids].to_numpy()
    distance_raw_ori = []
    
    raw_syn = pd.read_csv(raw_path)
    raw_syn = raw_syn[feature_ids].to_numpy()

    normalize_array(original)
    normalize_array(raw_syn)

    unit_distance_raw_ori = []

    for col_id in range(original.shape[1]):
        unit_distance_raw_ori.append(wasserstein_distance(original[:,col_id], raw_syn[:,col_id]))


    print('wasserstein_distance between original data and synthetic data:', sum(unit_distance_raw_ori) / len(unit_distance_raw_ori))
# Out:
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv
# wasserstein_distance between original data and synthetic data: 0.062263605564281746
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv
# wasserstein_distance between original data and synthetic data: 0.08184791330356357
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv
# wasserstein_distance between original data and synthetic data: 0.1929389332162287
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv
# wasserstein_distance between original data and synthetic data: 0.19247794637275645
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv
# wasserstein_distance between original data and synthetic data: 0.18594898040359387

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import jensenshannon
from scipy.stats import wasserstein_distance
from tqdm import tqdm

raw_path = r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\real.csv'
data_path =     [r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv']
def normalize_array(x):
    for col_id in range(x.shape[1]):
        x[:, col_id] = (x[:, col_id] - np.mean(x[:, col_id])) / np.std(x[:, col_id])

for task in data_path:
    print('-----------------------')
    print(task)
    original = pd.read_csv(task)
    original = original[original['label']==0]
    original = original[feature_ids].to_numpy()
    distance_raw_ori = []
    
    raw_syn = pd.read_csv(raw_path)
    raw_syn = raw_syn[raw_syn['label']==0]
    raw_syn = raw_syn[feature_ids].to_numpy()

    normalize_array(original)
    normalize_array(raw_syn)

    unit_distance_raw_ori = []

    for col_id in range(original.shape[1]):
        unit_distance_raw_ori.append(wasserstein_distance(original[:,col_id], raw_syn[:,col_id]))


    print('wasserstein_distance between original data and synthetic data:', sum(unit_distance_raw_ori) / len(unit_distance_raw_ori))
# Out:
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv
# wasserstein_distance between original data and synthetic data: 0.007498514234931909
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv
# wasserstein_distance between original data and synthetic data: 0.06697657620461313
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv
# wasserstein_distance between original data and synthetic data: 0.08471375943589603
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv
# wasserstein_distance between original data and synthetic data: 0.20550083892154802
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv
# wasserstein_distance between original data and synthetic data: 0.18601917230789744
# -----------------------
# ...

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import jensenshannon
from scipy.stats import wasserstein_distance
from tqdm import tqdm

raw_path = r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\real.csv'
data_path =     [r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv']
def normalize_array(x):
    for col_id in range(x.shape[1]):
        x[:, col_id] = (x[:, col_id] - np.mean(x[:, col_id])) / np.std(x[:, col_id])

for task in data_path:
    print('-----------------------')
    print(task)
    original = pd.read_csv(task)
    original = original[original['label']==1]
    original = original[feature_ids].to_numpy()
    distance_raw_ori = []
    
    raw_syn = pd.read_csv(raw_path)
    raw_syn = raw_syn[raw_syn['label']==1]
    raw_syn = raw_syn[feature_ids].to_numpy()

    normalize_array(original)
    normalize_array(raw_syn)

    unit_distance_raw_ori = []

    for col_id in range(original.shape[1]):
        unit_distance_raw_ori.append(wasserstein_distance(original[:,col_id], raw_syn[:,col_id]))


    print('wasserstein_distance between original data and synthetic data:', sum(unit_distance_raw_ori) / len(unit_distance_raw_ori))
# Out:
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv
# wasserstein_distance between original data and synthetic data: 0.016597954954212506
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv
# wasserstein_distance between original data and synthetic data: 0.0871004492694199
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv
# wasserstein_distance between original data and synthetic data: 0.15684601526915384
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv
# wasserstein_distance between original data and synthetic data: 0.23818127386898935
# -----------------------
# C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv
# wasserstein_distance between original data and synthetic data: 0.24724412001723728
# -----------------------
# ...

# %%
def balance(df):
    # 分离标签为1和不为1的样本
    positive_samples = df[df['label'] == 1]
    negative_samples = df[df['label'] != 1]

    negative_samples_downsampled = negative_samples.sample(n=len(positive_samples) * 1, random_state=50)

    # 合并数据集
    new_dataset = pd.concat([positive_samples, negative_samples_downsampled])
    return new_dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
from catboost import CatBoostClassifier

def balance(df):
    # 分离标签为1和不为1的样本
    positive_samples = df[df['label'] == 1]
    negative_samples = df[df['label'] != 1]

    negative_samples_downsampled = negative_samples.sample(n=len(positive_samples) * 1, random_state=50)

    # 合并数据集
    new_dataset = pd.concat([positive_samples, negative_samples_downsampled])
    return new_dataset

# 准备数据
dataset_paths = [
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\real.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv',
]
dataset_name = ['real','diffusion', 'dp/diffusion', 'dp/csm_1step', 'dp/csm_2step', 'dp/csm_5step']
colors = ['blue', 'purple', 'green', '#FF0000', '#FF4500', '#FFA500']

test_data_path = r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv'
test_data = pd.read_csv(test_data_path)
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']

plt.figure(figsize=(10, 8))

i=0
for path in dataset_paths:
    data = pd.read_csv(path)
    df = data.copy()

    new_dataset = balance(df)
    X_train = new_dataset.drop('label', axis=1).copy()
    y_train = new_dataset['label'].copy()
    
    new_dataset1 = balance(test_data)
    X_test = new_dataset1.drop('label', axis=1).copy()
    y_test = new_dataset1['label'].copy()
    
    model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=3, scale_pos_weight=len(y_train)/sum(y_train), silent=True)
    model.fit(X_train, y_train)

    pred_probs = model.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, pred_probs)
    auc_score = roc_auc_score(y_test, pred_probs)
    
    plt.plot(fpr, tpr, lw=2, label=f'{dataset_name[i]} (AUC = {auc_score:.3f})', color=colors[i])
    
    print('-----------------------------------')
    print(dataset_name[i])
    predictions = model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    i += 1


plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# -----------------------------------
# real
# Accuracy: 0.6912757340533243
# Precision: 0.635927569252908
# Recall: 0.8948700641241984
# -----------------------------------
# diffusion
# Accuracy: 0.6624198447519406
# Precision: 0.6069801044792709
# Recall: 0.9215322308471144
# -----------------------------------
# dp/diffusion
# Accuracy: 0.6299358758015525
# Precision: 0.5781408565049726
# Recall: 0.961356733040837
# -----------------------------------
# dp/csm_1step
# Accuracy: 0.6875632804589943
# Precision: 0.6440326551768822
# Recall: 0.8386770165372933
# -----------------------------------
# dp/csm_2step
# Accuracy: 0.6997131285858926
# Precision: 0.6618350881990975
# Recall: 0.8167397907526156
# -----------------------------------
# dp/csm_5step
# Accuracy: 0.7025818427269659
# Precision: 0.6847207262655793
# Recall: 0.7509281133985826

# %%
thresholds
# Out:
# array([1.9904507 , 0.9904507 , 0.98728784, ..., 0.01114551, 0.01111698,
#        0.00761831])

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
from catboost import CatBoostClassifier

dataset_paths = [
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\real.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_dpdf.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv',
    r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv',
]
dataset_name = ['real','diffusion', 'dp/diffusion', 'dp/csm_1step', 'dp/csm_2step', 'dp/csm_5step']
colors = ['blue', 'purple', 'green', '#FF0000', '#FF4500', '#FFA500']

test_data_path = r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv'
test_data = pd.read_csv(test_data_path)
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']

plt.figure(figsize=(10, 8))

i=0
for path in dataset_paths:
    data = pd.read_csv(path)
    df = data.copy()

    X_train = df.drop('label', axis=1)
    y_train = df['label']
    
    model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=3, scale_pos_weight=len(y_train)/sum(y_train), silent=True)
    model.fit(X_train, y_train)

    pred_probs = model.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, pred_probs)
    auc_score = roc_auc_score(y_test, pred_probs)
    print('-----------------------------------')
    print(dataset_name[i])
    predictions = model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    plt.plot(fpr, tpr, lw=2, label=f'{dataset_name[i]} (AUC = {auc_score:.3f})', color=colors[i])
    i += 1


plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# -----------------------------------
# real
# Accuracy: 0.728956087387948
# Precision: 0.23099260823653642
# Recall: 0.73827202159973
# -----------------------------------
# diffusion
# Accuracy: 0.7541667367429657
# Precision: 0.24055167472684935
# Recall: 0.6798852514343571
# -----------------------------------
# dp/diffusion
# Accuracy: 0.6740274811214451
# Precision: 0.2017201631494946
# Recall: 0.7678029024637192
# -----------------------------------
# dp/csm_1step
# Accuracy: 0.737213878470879
# Precision: 0.22863857646466343
# Recall: 0.689503881201485
# -----------------------------------
# dp/csm_2step
# Accuracy: 0.7427975579811299
# Precision: 0.23290561733675505
# Recall: 0.6891663854201823
# -----------------------------------
# dp/csm_5step
# Accuracy: 0.7950688709867304
# Precision: 0.2679617409357159
# Recall: 0.6098548768140398

# %%
# balance dp + 1-step consistency
data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']

new_dataset = balance(df)
X = new_dataset.drop('label', axis=1).copy()
y = new_dataset['label'].copy()

new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()

model = CatBoostClassifier(iterations=200, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
# 计算 ROC 曲线
fpr, tpr, thresholds = roc_curve(y_test, pred_probs)
auc_score = roc_auc_score(y_test, pred_probs)

# 绘制 ROC 曲线
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# balance dp + 2-step consistency
data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']

new_dataset = balance(df)
X = new_dataset.drop('label', axis=1).copy()
y = new_dataset['label'].copy()

new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()

model = CatBoostClassifier(iterations=200, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, pred_probs)
print("AUC Score:", auc_score)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# AUC Score: 0.8002071532703545
# Accuracy: 0.7015693553830578
# Precision: 0.6656497018444044
# Recall: 0.809989875126561

# %%
# balance dp + 5-step consistency
data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']

new_dataset = balance(df)
X = new_dataset.drop('label', axis=1).copy()
y = new_dataset['label'].copy()

new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()

model = CatBoostClassifier(iterations=200, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, pred_probs)
print("AUC Score:", auc_score)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# AUC Score: 0.7888873904263506
# Accuracy: 0.7034255821802228
# Precision: 0.6879775456104787
# Recall: 0.7445156935538306

# %%
# dp + diffutsion

data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\real.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']


X = df.drop('label', axis=1).copy()
y = df['label'].copy()

'''new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()'''

model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, pred_probs)
print("AUC Score:", auc_score)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# AUC Score: 0.8191375897477742
# Accuracy: 0.728956087387948
# Precision: 0.23099260823653642
# Recall: 0.73827202159973

# %%
# dp + diffutsion

data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']


X = df.drop('label', axis=1).copy()
y = df['label'].copy()

'''new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()'''

model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, pred_probs)
print("AUC Score:", auc_score)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# AUC Score: 0.8054477740866172
# Accuracy: 0.6740274811214451
# Precision: 0.2017201631494946
# Recall: 0.7678029024637192

# %%
# dp + 1-step

data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_1step.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']


X = df.drop('label', axis=1).copy()
y = df['label'].copy()

'''new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()'''

model = CatBoostClassifier(iterations=200, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, pred_probs)
print("AUC Score:", auc_score)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# AUC Score: 0.7956058472302552
# Accuracy: 0.7248356010023714
# Precision: 0.22307733135183908
# Recall: 0.7092473844076949

# %%
# dp + 2-step consistency model

data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_2step.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']


X = df.drop('label', axis=1).copy()
y = df['label'].copy()

'''new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()'''

model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, pred_probs)
print("AUC Score:", auc_score)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# AUC Score: 0.8000795245672789
# Accuracy: 0.7427975579811299
# Precision: 0.23290561733675505
# Recall: 0.6891663854201823

# %%
# dp + 5-step consistency model

data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\tabsyn_5step.csv')
test_data = pd.read_csv(r'C:\Users\RenJump\PycharmProjects\untitled\tabsyn\synthetic\amazon\test.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from catboost import CatBoostClassifier

# 假设sample_data已经加载到DataFrame df中
df = data.copy()
X_test = test_data.drop('label', axis=1)
y_test = test_data['label']


X = df.drop('label', axis=1).copy()
y = df['label'].copy()

'''new_dataset = balance(test_data)
X_test = new_dataset.drop('label', axis=1).copy()
y_test = new_dataset['label'].copy()'''

model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=3, scale_pos_weight=len(y)/sum(y),silent = True)

# 训练模型
model.fit(X, y)

# 预测测试集
predictions = model.predict(X_test)

pred_probs = model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, pred_probs)
print("AUC Score:", auc_score)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# AUC Score: 0.7964847024345789
# Accuracy: 0.7950688709867304
# Precision: 0.2679617409357159
# Recall: 0.6098548768140398
